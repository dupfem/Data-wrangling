# %% [markdown]
# # Data Wrangling

# %%
# import libraries

import pandas as pd

# %%
# load data

data = pd.read_csv('Marketing_Data.csv')

# %%
data
# Out:
#       Income  Kidhome  Teenhome  Recency  MntWines  MntFruits  \
# 0      58138        0         0       58       635         88
# 1      46344        1         1       38        11          1
# 2      71613        0         0       26       426         49
# 3      26646        1         0       26        11          4
# 4      58293        1         0       94       173         43
# ...      ...      ...       ...      ...       ...        ...
# 2200   61223        0         1       46       709         43
# 2201   64014        2         1       56       406          0
# 2202   56981        0         0       91       908         48
# 2203   69245        0         1        8       428         30
# 2204   52869        1         1       40        84          3
#
#       MntMeatProducts  MntFishProducts  MntSweetProducts  MntGoldProds  ...  \
# 0                 546              172                88            88  ...
# ...

# %%
# inspect for missing values
data.isna().sum()
# Out:
# Income                  0
# Kidhome                 0
# Teenhome                0
# Recency                 0
# MntWines                0
# MntFruits               0
# MntMeatProducts         0
# MntFishProducts         0
# MntSweetProducts        0
# MntGoldProds            0
# NumDealsPurchases       0
# NumWebPurchases         0
# NumCatalogPurchases     0
# NumStorePurchases       0
# NumWebVisitsMonth       0
# AcceptedCmp3            0
# AcceptedCmp4            0
# AcceptedCmp5            0
# AcceptedCmp1            0
# AcceptedCmp2            0
# Complain                0
# Z_CostContact           0
# Z_Revenue               0
# Response                0
# Age                     0
# Customer_Days           0
# marital_Divorced        0
# marital_Married         0
# marital_Single          0
# marital_Together        0
# marital_Widow           0
# education_2n Cycle      0
# education_Basic         0
# education_Graduation    0
# education_Master        0
# ...

# %%
# drop missing values
#data = df.dropna()

# %%
data.shape
# Out:
# (2205, 39)

# %%
#check if the data is no longer having missing values

# %%
data.dtypes
# Out:
# Income                  int64
# Kidhome                 int64
# Teenhome                int64
# Recency                 int64
# MntWines                int64
# MntFruits               int64
# MntMeatProducts         int64
# MntFishProducts         int64
# MntSweetProducts        int64
# MntGoldProds            int64
# NumDealsPurchases       int64
# NumWebPurchases         int64
# NumCatalogPurchases     int64
# NumStorePurchases       int64
# NumWebVisitsMonth       int64
# AcceptedCmp3            int64
# AcceptedCmp4            int64
# AcceptedCmp5            int64
# AcceptedCmp1            int64
# AcceptedCmp2            int64
# Complain                int64
# Z_CostContact           int64
# Z_Revenue               int64
# Response                int64
# Age                     int64
# Customer_Days           int64
# marital_Divorced        int64
# marital_Married         int64
# marital_Single          int64
# marital_Together        int64
# marital_Widow           int64
# ...

# %%
# checking for duplicates
data.duplicated().sum()
# Out:
# 184

# %%
# removing duplicates

data.drop_duplicates(keep='first')
# Out:
#       Income  Kidhome  Teenhome  Recency  MntWines  MntFruits  \
# 0      58138        0         0       58       635         88
# 1      46344        1         1       38        11          1
# 2      71613        0         0       26       426         49
# 3      26646        1         0       26        11          4
# 4      58293        1         0       94       173         43
# ...      ...      ...       ...      ...       ...        ...
# 2198   26816        0         0       50         5          1
# 2200   61223        0         1       46       709         43
# 2202   56981        0         0       91       908         48
# 2203   69245        0         1        8       428         30
# 2204   52869        1         1       40        84          3
#
#       MntMeatProducts  MntFishProducts  MntSweetProducts  MntGoldProds  ...  \
# 0                 546              172                88            88  ...
# ...

# %%
df = data.drop_duplicates(keep='first')

# %%
df
# Out:
#       Income  Kidhome  Teenhome  Recency  MntWines  MntFruits  \
# 0      58138        0         0       58       635         88
# 1      46344        1         1       38        11          1
# 2      71613        0         0       26       426         49
# 3      26646        1         0       26        11          4
# 4      58293        1         0       94       173         43
# ...      ...      ...       ...      ...       ...        ...
# 2198   26816        0         0       50         5          1
# 2200   61223        0         1       46       709         43
# 2202   56981        0         0       91       908         48
# 2203   69245        0         1        8       428         30
# 2204   52869        1         1       40        84          3
#
#       MntMeatProducts  MntFishProducts  MntSweetProducts  MntGoldProds  ...  \
# 0                 546              172                88            88  ...
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
# summary of descriptive stastitics

df.describe().T
# Out:
#                        count          mean           std     min      25%  \
# Income                2021.0  51687.258783  20713.046401  1730.0  35416.0
# Kidhome               2021.0      0.443345      0.536196     0.0      0.0
# Teenhome              2021.0      0.509649      0.546393     0.0      0.0
# Recency               2021.0     48.880752     28.950917     0.0     24.0
# MntWines              2021.0    306.492331    337.603877     0.0     24.0
# MntFruits             2021.0     26.364671     39.776518     0.0      2.0
# MntMeatProducts       2021.0    166.059871    219.869126     0.0     16.0
# MntFishProducts       2021.0     37.603662     54.892196     0.0      3.0
# MntSweetProducts      2021.0     27.268679     41.575454     0.0      1.0
# MntGoldProds          2021.0     43.921821     51.678211     0.0      9.0
# NumDealsPurchases     2021.0      2.330035      1.892778     0.0      1.0
# NumWebPurchases       2021.0      4.115289      2.753588     0.0      2.0
# ...

# %%
df.hist()
# Out:
# array([[<AxesSubplot: title={'center': 'Income'}>,
#         <AxesSubplot: title={'center': 'Kidhome'}>,
#         <AxesSubplot: title={'center': 'Teenhome'}>,
#         <AxesSubplot: title={'center': 'Recency'}>,
#         <AxesSubplot: title={'center': 'MntWines'}>,
#         <AxesSubplot: title={'center': 'MntFruits'}>],
#        [<AxesSubplot: title={'center': 'MntMeatProducts'}>,
#         <AxesSubplot: title={'center': 'MntFishProducts'}>,
#         <AxesSubplot: title={'center': 'MntSweetProducts'}>,
#         <AxesSubplot: title={'center': 'MntGoldProds'}>,
#         <AxesSubplot: title={'center': 'NumDealsPurchases'}>,
#         <AxesSubplot: title={'center': 'NumWebPurchases'}>],
#        [<AxesSubplot: title={'center': 'NumCatalogPurchases'}>,
#         <AxesSubplot: title={'center': 'NumStorePurchases'}>,
#         <AxesSubplot: title={'center': 'NumWebVisitsMonth'}>,
#         <AxesSubplot: title={'center': 'AcceptedCmp3'}>,
# ...

# %%
# Information we can expect from .describe()


1. meaure of scale across features in the data # ReScaling
2. measure of gaussian behavior of the data - normal distribution # Normalization
3. Measure of error or measure of dispersion in the data # Standardization
4. measure of skewness in the data: # de-Skew

# %%
df.Income.plot(kind='density')
# Out:
# <AxesSubplot: ylabel='Density'>

# %%
df.MntWines.plot(kind='density')
# Out:
# <AxesSubplot: ylabel='Density'>

# %%
df.Age.plot(kind='density')
# Out:
# <AxesSubplot: ylabel='Density'>
